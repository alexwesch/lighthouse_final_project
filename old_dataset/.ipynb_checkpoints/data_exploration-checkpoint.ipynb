# %%
import pandas as pd
import numpy as np

# %%
import matplotlib.pyplot as plt
import seaborn as SNS
# %matplotlib inline

# %%
data2010 = pd.read_excel('online_retail_II.xlsx' , sheet_name='Year 2009-2010')
data2011 = pd.read_excel('online_retail_II.xlsx', sheet_name='Year 2010-2011')

# %%
data2011.shape
# Out:
# (541910, 8)

# %%
datafull = pd.concat([data2010, data2011]).drop_duplicates()

# %%
datafull.shape
# Out:
# (1033036, 17)

# %%
datafull.isnull().any()
# Out:
# Invoice        False
# StockCode      False
# Description     True
# Quantity       False
# InvoiceDate    False
# Price          False
# Customer ID     True
# Country        False
# Day            False
# Week           False
# Month          False
# Year           False
# DayofYear      False
# Sales          False
# Type           False
# DayofWeek      False
# Date           False
# dtype: bool

# %%
datafull.head(20)
# Out:
#    Invoice StockCode                          Description  Quantity  \
# 0   489434     85048  15CM CHRISTMAS GLASS BALL 20 LIGHTS        12
# 1   489434    79323P                   PINK CHERRY LIGHTS        12
# 2   489434    79323W                  WHITE CHERRY LIGHTS        12
# 3   489434     22041         RECORD FRAME 7" SINGLE SIZE         48
# 4   489434     21232       STRAWBERRY CERAMIC TRINKET BOX        24
# 5   489434     22064           PINK DOUGHNUT TRINKET POT         24
# 6   489434     21871                  SAVE THE PLANET MUG        24
# 7   489434     21523   FANCY FONT HOME SWEET HOME DOORMAT        10
# 8   489435     22350                            CAT BOWL         12
# 9   489435     22349       DOG BOWL , CHASING BALL DESIGN        12
# 10  489435     22195         HEART MEASURING SPOONS LARGE        24
# 11  489435     22353   LUNCHBOX WITH CUTLERY FAIRY CAKES         12
# 12  489436    48173C                DOOR MAT BLACK FLOCK         10
# ...

# %%
datafull[datafull['InvoiceDate'].dt.strftime('%Y-%m-%d') == "2011-01-04"]
# Out:
#        Invoice StockCode                          Description  Quantity  \
# 42481   539993     22386              JUMBO BAG PINK POLKADOT        10
# 42482   539993     21499                   BLUE POLKADOT WRAP        25
# 42483   539993     21498                  RED RETROSPOT WRAP         25
# 42484   539993     22379             RECYCLING BAG RETROSPOT          5
# 42485   539993     20718            RED RETROSPOT SHOPPER BAG        10
# ...        ...       ...                                  ...       ...
# 43660   540099    85099C       JUMBO  BAG BAROQUE BLACK WHITE        20
# 43661   540099    85099B              JUMBO BAG RED RETROSPOT        13
# 43662   540100     22837                                    ?      -106
# 43663  C540109    85071A  BLUE CHARLIE+LOLA PERSONAL DOORSIGN      -150
# 43664  C540112     21735               TWO DOOR CURIO CABINET       -18
#
#               InvoiceDate  Price  Customer ID         Country  Day  Week  \
# ...

# %%
datafull.dtypes
# Out:
# Invoice                object
# StockCode              object
# Description            object
# Quantity                int64
# InvoiceDate    datetime64[ns]
# Price                 float64
# Customer ID           float64
# Country                object
# dtype: object

# %%
datafull.count()
# Out:
# Invoice        1033036
# StockCode      1033036
# Description    1028761
# Quantity       1033036
# InvoiceDate    1033036
# Price          1033036
# Customer ID     797885
# Country        1033036
# Sales          1033036
# Day            1033036
# Month          1033036
# Year           1033036
# dtype: int64

# %%
datafull.nunique()
# Out:
# Invoice        53628
# StockCode       5305
# Description     5698
# Quantity        1057
# InvoiceDate    47635
# Price           2807
# Customer ID     5942
# Country           43
# Sales           9113
# Day               31
# Month             12
# Year               3
# dtype: int64

# %%
datafull['Day'] = datafull['InvoiceDate'].dt.day
datafull['Week'] = datafull['InvoiceDate'].dt.week
datafull['Month'] = datafull['InvoiceDate'].dt.month
datafull['Year'] = datafull['InvoiceDate'].dt.year
datafull['DayofYear'] = datafull['InvoiceDate'].dt.dayofyear
datafull['DayofWeek'] = datafull['InvoiceDate'].dt.dayofweek
# Out:
# C:\Users\Alex\AppData\Local\Temp\ipykernel_349880\1420079495.py:2: FutureWarning: Series.dt.weekofyear and Series.dt.week have been deprecated. Please use Series.dt.isocalendar().week instead.
#   datafull['Week'] = datafull['InvoiceDate'].dt.week

# %%
datafull['Date'] = datafull['InvoiceDate'].dt.date

# %%
datafull['DayofWeek'].value_counts()
# Out:
# 3    196189
# 1    191972
# 0    183699
# 2    177445
# 4    150312
# 6    133017
# 5       402
# Name: DayofWeek, dtype: int64

# %%
datafull['Sales'] = datafull['Quantity'] * datafull['Price']

# %%
datafull.head(20)
# Out:
#    Invoice StockCode                          Description  Quantity  \
# 0   489434     85048  15CM CHRISTMAS GLASS BALL 20 LIGHTS        12
# 1   489434    79323P                   PINK CHERRY LIGHTS        12
# 2   489434    79323W                  WHITE CHERRY LIGHTS        12
# 3   489434     22041         RECORD FRAME 7" SINGLE SIZE         48
# 4   489434     21232       STRAWBERRY CERAMIC TRINKET BOX        24
# 5   489434     22064           PINK DOUGHNUT TRINKET POT         24
# 6   489434     21871                  SAVE THE PLANET MUG        24
# 7   489434     21523   FANCY FONT HOME SWEET HOME DOORMAT        10
# 8   489435     22350                            CAT BOWL         12
# 9   489435     22349       DOG BOWL , CHASING BALL DESIGN        12
# 10  489435     22195         HEART MEASURING SPOONS LARGE        24
# 11  489435     22353   LUNCHBOX WITH CUTLERY FAIRY CAKES         12
# 12  489436    48173C                DOOR MAT BLACK FLOCK         10
# ...

# %%
monthlysales = datafull.groupby(['Year', 'Month'])['Sales'].sum()

# %%
weeklysales = datafull.groupby(['Year', 'Week'])['Sales'].sum()

# %%
dailysales = datafull.groupby(['Year', 'DayofYear'])['Sales'].sum()

# %%
date_list=[]
for date in monthlysales.index.to_list():
    date_str = str(date[0])+" " +str(date[1])
    date_list.append(date_str)

# %%
wdate_list=[]
for date in weeklysales.index.to_list():
    date_str = str(date[0])+" " +str(date[1])
    wdate_list.append(date_str)

# %%
ddate_list=[]
for date in dailysales.index.to_list():
    date_str = str(date[0])+" " +str(date[1])
    ddate_list.append(date_str)

# %%
datafull.sort_values(by = 'Sales',ascending=True).tail(20)
# Out:
#         Invoice  StockCode                          Description  Quantity  \
# 440698   531411  AMAZONFEE                           AMAZON FEE         1
# 129903   501766          M                               Manual         1
# 129987   501768          M                               Manual         1
# 374227   525473          M                               Manual         1
# 348325   567423      23243  SET OF TEA COFFEE SUGAR TINS PANTRY      1412
# 173382   551697       POST                              POSTAGE         1
# 228042   511465     15044A                  PINK PAPER PARASOL       3500
# 74356    496115          M                               Manual         1
# 358639   524159          M                               Manual         1
# 372834   525399          M                               Manual         1
# 342147   522796          M                               Manual         1
# 135015   502265          M                               Manual         1
# ...

# %%
datafull['Customer ID'].min()
# Out:
# 12346.0

# %%
datafull.loc[datafull['Invoice'] == 511465]
# Out:
#        Invoice StockCode          Description  Quantity         InvoiceDate  \
# 228041  511465    15044B  BLUE PAPER PARASOL        500 2010-06-08 12:59:00
# 228042  511465    15044A  PINK PAPER PARASOL       3500 2010-06-08 12:59:00
#
#         Price  Customer ID         Country  Day  Week  Month  Year  DayofYear  \
# 228041   2.55      18008.0  United Kingdom    8    23      6  2010        159
# 228042   2.55      18008.0  United Kingdom    8    23      6  2010        159
#
#          Sales  Type  DayofWeek        Date
# 228041  1275.0  Sale          1  2010-06-08
# 228042  8925.0  Sale          1  2010-06-08

# %%
datafull.loc[datafull['Customer ID'] == 16446.0]
# Out:
#         Invoice StockCode                  Description  Quantity  \
# 371780  C525275   TEST001      This is a test product.        -2
# 194354   553573     22980       PANTRY SCRUBBING BRUSH         1
# 194355   553573     22982          PANTRY PASTRY BRUSH         1
# 540421   581483     23843  PAPER CRAFT , LITTLE BIRDIE     80995
# 540422  C581484     23843  PAPER CRAFT , LITTLE BIRDIE    -80995
#
#                InvoiceDate  Price  Customer ID         Country  Day  Week  \
# 371780 2010-10-04 16:38:00   4.50      16446.0  United Kingdom    4    40
# 194354 2011-05-18 09:52:00   1.65      16446.0  United Kingdom   18    20
# 194355 2011-05-18 09:52:00   1.25      16446.0  United Kingdom   18    20
# 540421 2011-12-09 09:15:00   2.08      16446.0  United Kingdom    9    49
# 540422 2011-12-09 09:27:00   2.08      16446.0  United Kingdom    9    49
#
#         Month  Year  DayofYear      Sales       Type  DayofWeek        Date
# ...

# %%
datafull.loc[datafull['Customer ID'] == 15098.0]
# Out:
#         Invoice StockCode                     Description  Quantity  \
# 222670   556442     22502      PICNIC BASKET WICKER SMALL        60
# 222671   556444     22502  PICNIC BASKET WICKER 60 PIECES        60
# 222681  C556445         M                          Manual        -1
# 222682   556446     22502  PICNIC BASKET WICKER 60 PIECES         1
# 222692  C556448     22502      PICNIC BASKET WICKER SMALL       -60
#
#                InvoiceDate     Price  Customer ID         Country  Day  Week  \
# 222670 2011-06-10 15:22:00      4.95      15098.0  United Kingdom   10    23
# 222671 2011-06-10 15:28:00    649.50      15098.0  United Kingdom   10    23
# 222681 2011-06-10 15:31:00  38970.00      15098.0  United Kingdom   10    23
# 222682 2011-06-10 15:33:00    649.50      15098.0  United Kingdom   10    23
# 222692 2011-06-10 15:39:00      4.95      15098.0  United Kingdom   10    23
#
#         Month  Year  DayofYear    Sales       Type  DayofWeek        Date
# ...

# %%
datafull.loc[datafull['Customer ID'] == 16446.0]
# Out:
#         Invoice StockCode                  Description  Quantity  \
# 371780  C525275   TEST001      This is a test product.        -2
# 194354   553573     22980       PANTRY SCRUBBING BRUSH         1
# 194355   553573     22982          PANTRY PASTRY BRUSH         1
# 540421   581483     23843  PAPER CRAFT , LITTLE BIRDIE     80995
# 540422  C581484     23843  PAPER CRAFT , LITTLE BIRDIE    -80995
#
#                InvoiceDate  Price  Customer ID         Country  Day  Week  \
# 371780 2010-10-04 16:38:00   4.50      16446.0  United Kingdom    4    40
# 194354 2011-05-18 09:52:00   1.65      16446.0  United Kingdom   18    20
# 194355 2011-05-18 09:52:00   1.25      16446.0  United Kingdom   18    20
# 540421 2011-12-09 09:15:00   2.08      16446.0  United Kingdom    9    49
# 540422 2011-12-09 09:27:00   2.08      16446.0  United Kingdom    9    49
#
#         Month  Year  DayofYear      Sales       Type  DayofWeek        Date
# ...

# %%
datasales[datasales['Customer ID'].isna()]
# Out:
#         Invoice StockCode                     Description  Quantity  \
# 532      489525    85226C       BLUE PULL BACK RACING CAR         1
# 533      489525     85227     SET/6 3D KIT CARDS FOR KIDS         1
# 977      489548     22271            FELTCRAFT DOLL ROSIE         1
# 978      489548     22254            FELT TOADSTOOL LARGE        12
# 979      489548     22273            FELTCRAFT DOLL MOLLY         3
# ...         ...       ...                             ...       ...
# 1002678  581498    85049e       SCANDINAVIAN REDS RIBBONS         4
# 1002679  581498    85099B         JUMBO BAG RED RETROSPOT         5
# 1002680  581498    85099C  JUMBO  BAG BAROQUE BLACK WHITE         4
# 1002681  581498     85150   LADIES & GENTLEMEN METAL SIGN         1
# 1002682  581498     85174               S/4 CACTI CANDLES         1
#
#                 InvoiceDate  Price  Customer ID         Country  Day  Week  \
# ...

# %%
plt.bar(date_list,monthlysales)
# Out:
# <BarContainer object of 25 artists>

# %%
plt.bar(wdate_list,weeklysales)
# Out:
# <BarContainer object of 104 artists>

# %%
plt.bar(ddate_list,dailysales)
# Out:
# <BarContainer object of 604 artists>

# %%
datafull.groupby(['StockCode']).mean()
# Out:
#                 Quantity      Price   Customer ID      Sales        Day  \
# StockCode
# 10002          20.279255   0.970160  14995.666667  16.113590  14.917553
# 10080          19.258065   0.456129  15937.555556   4.170645  14.419355
# 10109           0.000000   0.210000  14159.000000   0.840000   3.500000
# 10120        -111.546667   0.236533  15976.031746   1.819200  13.200000
# 10125          12.156069   0.930636  15160.388889   9.917803  14.000000
# ...                  ...        ...           ...        ...        ...
# gift_0001_60    6.500000   0.000000           NaN   0.000000  19.000000
# gift_0001_70    4.333333  19.856667           NaN  19.856667  17.333333
# gift_0001_80    3.000000  34.780000           NaN   0.000000  12.750000
# gift_0001_90    6.000000   0.000000           NaN   0.000000  19.000000
# m               1.000000   3.010000           NaN   3.010000  16.000000
#
#                  Month         Year
# StockCode
# 10002         6.696809  2010.061170
# ...

# %%
datafull.loc[datafull['StockCode'] == 'POST']
# Out:
#         Invoice StockCode Description  Quantity         InvoiceDate   Price  \
# 89       489439      POST     POSTAGE         3 2009-12-01 09:28:00   18.00
# 126      489444      POST     POSTAGE         1 2009-12-01 09:55:00  141.00
# 173      489447      POST     POSTAGE         1 2009-12-01 10:10:00  130.00
# 625      489526      POST     POSTAGE         6 2009-12-01 11:50:00   18.00
# 927     C489538      POST     POSTAGE        -1 2009-12-01 12:18:00    9.58
# ...         ...       ...         ...       ...                 ...     ...
# 541216   581494      POST     POSTAGE         2 2011-12-09 10:13:00   18.00
# 541730   581570      POST     POSTAGE         1 2011-12-09 11:59:00   18.00
# 541767   581574      POST     POSTAGE         2 2011-12-09 12:09:00   18.00
# 541768   581578      POST     POSTAGE         3 2011-12-09 12:16:00   18.00
# 541909   581587      POST     POSTAGE         1 2011-12-09 12:50:00   18.00
#
# ...

# %%
datafull.loc[datafull['Sales'] < 0]
# Out:
#         Invoice StockCode                       Description  Quantity  \
# 178     C489449     22087          PAPER BUNTING WHITE LACE       -12
# 179     C489449    85206A      CREAM FELT EASTER EGG BASKET        -6
# 180     C489449     21895     POTTING SHED SOW 'N' GROW SET        -4
# 181     C489449     21896                POTTING SHED TWINE        -6
# 182     C489449     22083        PAPER CHAIN KIT RETRO SPOT       -12
# ...         ...       ...                               ...       ...
# 540449  C581490     23144   ZINC T-LIGHT HOLDER STARS SMALL       -11
# 541541  C581499         M                            Manual        -1
# 541715  C581568     21258        VICTORIAN SEWING BOX LARGE        -5
# 541716  C581569     84978  HANGING HEART JAR T-LIGHT HOLDER        -1
# 541717  C581569     20979     36 PENCILS TUBE RED RETROSPOT        -5
#
#                InvoiceDate   Price  Customer ID         Country   Sales  Day  \
# ...

# %%
datafull.loc[datafull['Invoice'] == 'C489538']
# Out:
#      Invoice StockCode                        Description  Quantity  \
# 926  C489538     22183  CAKE STAND VICTORIAN FILIGREE MED        -4
# 927  C489538      POST                            POSTAGE        -1
#
#             InvoiceDate  Price  Customer ID         Country  Sales  Day  \
# 926 2009-12-01 12:18:00   6.75      15796.0  United Kingdom -27.00    1
# 927 2009-12-01 12:18:00   9.58      15796.0  United Kingdom  -9.58    1
#
#      Month  Year    Type
# 926     12  2009  Return
# 927     12  2009  Return

# %%
datafull.loc[datafull['StockCode'] == 22183]
# Out:
#         Invoice StockCode                        Description  Quantity  \
# 926     C489538     22183  CAKE STAND VICTORIAN FILIGREE MED        -4
# 5102     489856     22183  CAKE STAND VICTORIAN FILIGREE MED         2
# 6423     489888     22183  CAKE STAND VICTORIAN FILIGREE MED         3
# 6788     489998     22183  CAKE STAND VICTORIAN FILIGREE MED         3
# 19683   C491021     22183  CAKE STAND VICTORIAN FILIGREE MED        -1
# ...         ...       ...                                ...       ...
# 201613   554310     22183  CAKE STAND VICTORIAN FILIGREE MED         3
# 203314   554514     22183  CAKE STAND VICTORIAN FILIGREE MED        12
# 204758   554694     22183  CAKE STAND VICTORIAN FILIGREE MED         1
# 265147   560209     22183  CAKE STAND VICTORIAN FILIGREE MED         1
# 461945   575957     22183  CAKE STAND VICTORIAN FILIGREE MED         1
#
#                InvoiceDate  Price  Customer ID         Country  Sales  Day  \
# ...

# %%
datafull.loc[datafull['Customer ID'] == 15796].groupby('Invoice').sum()
# Out:
#          Quantity   Price  Customer ID  Day  Week  Month   Year  DayofYear  \
# Invoice
# 503343         82   40.80     252736.0  496   208     48  32160       1440
# 504853        163  145.58     552860.0  630   525    140  70350       3780
# 511057        220  107.55     410696.0  156   572    156  52260       4082
# 515337         66   34.64     126368.0   88   216     56  16080       1536
# 522115        139   86.34     394900.0  300   900    225  50250       6375
# 528754         93   99.02     379104.0  576  1008    240  48240       7128
# 530431         34   61.55     142164.0   27   396     99  18090       2763
# 535379         53   82.75     189552.0  300   564    132  24120       3948
# 536063         23   28.00      94776.0  180   288     66  12060       2004
# 543626        124   65.67     300124.0  190   114     38  38209        779
# 552259         91   72.10     379104.0  192   432    120  48264       3072
# ...

# %%
datafull['Type'] = datafull['Sales'].apply(lambda x: "Sale" if x > 0 else "Cancelled" if x < 0 else 'Other')

# %%
datafull
# Out:
#        Invoice StockCode                          Description  Quantity  \
# 0       489434     85048  15CM CHRISTMAS GLASS BALL 20 LIGHTS        12
# 1       489434    79323P                   PINK CHERRY LIGHTS        12
# 2       489434    79323W                  WHITE CHERRY LIGHTS        12
# 3       489434     22041         RECORD FRAME 7" SINGLE SIZE         48
# 4       489434     21232       STRAWBERRY CERAMIC TRINKET BOX        24
# ...        ...       ...                                  ...       ...
# 541905  581587     22899         CHILDREN'S APRON DOLLY GIRL          6
# 541906  581587     23254        CHILDRENS CUTLERY DOLLY GIRL          4
# 541907  581587     23255      CHILDRENS CUTLERY CIRCUS PARADE         4
# 541908  581587     22138        BAKING SET 9 PIECE RETROSPOT          3
# 541909  581587      POST                              POSTAGE         1
#
#                InvoiceDate  Price  Customer ID         Country  Day  Week  \
# ...

# %%
values = [x for x in datafull['StockCode'].unique() if str(x).isalpha()]

# %%
cancelled = [x for x in datafull['Invoice'].unique() if str(x).startswith('C')]

# %%
len(cancelled)
# Out:
# 8292

# %%
values
# Out:
# ['POST',
#  'D',
#  'DOT',
#  'M',
#  'PADS',
#  'ADJUST',
#  'DCGSSGIRL',
#  'GIFT',
#  'DCGSLBOY',
#  'm',
#  'DCGSSBOY',
#  'DCGSLGIRL',
#  'S',
#  'B',
#  'AMAZONFEE',
#  'CRUK']

# %%
datasales[datasales['DayofWeek']==5]
# Out:
#       Invoice StockCode                       Description  Quantity  \
# 11672  490363     84950    ASSORTED COLOUR T-LIGHT HOLDER       192
# 11673  490364     48185               DOOR MAT FAIRY CAKE         4
# 11674  490364     84836       ZINC METAL HEART DECORATION        12
# 11675  490364     22415                 WHITE TISSUE REAM         1
# 11676  490364     48187              DOOR MAT NEW ENGLAND         4
# ...       ...       ...                               ...       ...
# 12067  490394     21955  UNION JACK GUNS & ROSES  DOORMAT         6
# 12068  490394    85014A  BLACK/BLUE DOTS RUFFLED UMBRELLA        12
# 12069  490394    15056N         EDWARDIAN PARASOL NATURAL        12
# 12070  490394     20679             EDWARDIAN PARASOL RED        12
# 12071  490394    85014B   RED/WHITE DOTS RUFFLED UMBRELLA        12
#
#               InvoiceDate  Price  Customer ID         Country  Day  Week  \
# 11672 2009-12-05 10:11:00   0.72      13199.0  United Kingdom    5    49
# ...

# %%
values
# Out:
# ['POST',
#  'D',
#  'DCGS0058',
#  'DCGS0068',
#  'DOT',
#  'M',
#  'DCGS0004',
#  'DCGS0076',
#  'C2',
#  'BANK CHARGES',
#  'DCGS0003',
#  'TEST001',
#  'gift_0001_80',
#  'DCGS0072',
#  'gift_0001_20',
#  'DCGS0044',
#  'TEST002',
#  'gift_0001_10',
#  'gift_0001_50',
#  'DCGS0066N',
#  'gift_0001_30',
#  'PADS',
#  'ADJUST',
#  'gift_0001_40',
#  'gift_0001_60',
#  'gift_0001_70',
#  'gift_0001_90',
#  'DCGSSGIRL',
#  'DCGS0006',
#  'DCGS0016',
#  'DCGS0027',
#  'DCGS0036',
#  'DCGS0039',
#  'DCGS0060',
#  'DCGS0056',
#  'DCGS0059',
#  'GIFT',
#  'DCGSLBOY',
#  'm',
#  'DCGS0053',
#  'DCGS0062',
#  'DCGS0037',
#  'DCGSSBOY',
#  'DCGSLGIRL',
#  'S',
#  'DCGS0069',
#  'DCGS0070',
#  'DCGS0075',
#  'B',
#  'DCGS0041',
#  'ADJUST2',
#  'C3',
#  'SP1002',
#  'AMAZONFEE',
#  'DCGS0055',
#  'DCGS0074',
#  'DCGS0057',
#  'DCGS0073',
#  'DCGS0071',
#  'DCGS0066P',
#  'DCGS0067',
#  'CRUK']

# %%
adjustment = ['ADJUST', 'ADJUST2', 'D','M','m']
fees = ['BANK CHARGES', 'AMAZONFEE', 'CRUK']
postage = ['POST', 'dot', 'C2', 'DOT']
overhead = ['PAD']
writeoff = ['B']
samples = ['S', 'DCGSSBOY', 'DCGSSGIRL', 'DCGSLBOY', 'DCGSLGIRL']
unused = ['GIFT', 'C3', 'TEST002', 'TEST001']
gift_cards = ['gift_0001_10','gift_0001_50','gift_0001_30','gift_0001_40','gift_0001_70','gift_0001_90','gift_0001_20','gift_0001_80']

# %%
droplst = ['D','M','m', 'BANK CHARGES', 'AMAZONFEE', 'CRUK', 'POST', 'dot', 'C2','PAD','B','S', 'GIFT', 'C3', 'TEST002', 'TEST001', 'DOT', 'ADJUST', 'ADJUST2']

# %%
datasales = datafull[datafull.Type ==  'Sale']

# %%
datasales = datasales[datasales.StockCode.isin(droplst) == False]

# %%
datasales = datasales[datasales.DayofWeek !=  5]

# %%
datasales = datasales.reset_index(drop = True)

# %%
datasales.to_csv('sales.csv')

# %%
datasales['DayofWeek'].value_counts()
# Out:
# 3    189829
# 1    185862
# 0    179096
# 2    172558
# 4    145502
# 6    131641
# 5       400
# Name: DayofWeek, dtype: int64

# %%
datasales.groupby(['DayofWeek'])['Sales'].mean()
# Out:
# DayofWeek
# 0    19.115655
# 1    20.918827
# 2    19.590856
# 3    21.149763
# 4    21.814650
# 6    13.561237
# Name: Sales, dtype: float64

# %%
datasales.sort_values(by = 'Sales',ascending=True).tail(20)
# Out:
#        Invoice StockCode                          Description  Quantity  \
# 401504  529613     22423             REGENCY CAKESTAND 3 TIER       360
# 530628  540689     22470                HEART OF WICKER LARGE      1284
# 431651  532358     84879        ASSORTED COLOUR BIRD ORNAMENT      2880
# 761075  562439     84879        ASSORTED COLOUR BIRD ORNAMENT      2880
# 634927  550461     48185                   DOORMAT FAIRY CAKE       670
# 715778  558526     23173                REGENCY TEAPOT ROSES        540
# 342271  524181     21622     VINTAGE UNION JACK CUSHION COVER       648
# 531227  540818     48185                   DOORMAT FAIRY CAKE       670
# 634925  550461    85123A   WHITE HANGING HEART T-LIGHT HOLDER      1930
# 931406  576365     22086      PAPER CHAIN KIT 50'S CHRISTMAS        688
# 531165  540815    85123A   WHITE HANGING HEART T-LIGHT HOLDER      1930
# 886760  573003     23084                   RABBIT NIGHT LIGHT      2400
# ...

# %%
datasales = datasales[datasales['Invoice'] != 581483]
datasales = datasales[datasales['Invoice'] != 556444]
datasales = datasales[datasales['Customer ID'] != 123456]

# %%
plt.boxplot(datasales.sort_values(by = 'Sales',ascending=True)['Sales'])
# Out:
# {'whiskers': [<matplotlib.lines.Line2D at 0x247a32b5ba0>,
# ...
#  'caps': [<matplotlib.lines.Line2D at 0x247a32b55d0>,
# ...
#  'boxes': [<matplotlib.lines.Line2D at 0x2478a655330>],
#  'medians': [<matplotlib.lines.Line2D at 0x247a32b7cd0>],
#  'fliers': [<matplotlib.lines.Line2D at 0x247a32b6950>],
#  'means': []}

# %%
datasales.groupby('StockCode')['Price'].nunique()
# Out:
# StockCode
# 10002           5
# 10080           2
# 10109           1
# 10120           2
# 10125           7
#                ..
# gift_0001_30    3
# gift_0001_40    3
# gift_0001_50    3
# gift_0001_70    1
# gift_0001_80    1
# Name: Price, Length: 4904, dtype: int64

# %%
datasales[datasales['DayofWeek']==5]

# %%
monthlysales = datasales.groupby(['Year', 'Month'])['Sales'].sum()

# %%
weeklysales = datasales.groupby(['Year', 'Week'])['Sales'].sum()

# %%
dailysales = datasales.groupby(['Year', 'DayofYear'])['Sales'].sum()

# %%
date_list=[]
for date in monthlysales.index.to_list():
    date_str = str(date[0])+" " +str(date[1])
    date_list.append(date_str)

# %%
wdate_list=[]
for date in weeklysales.index.to_list():
    date_str = str(date[0])+" " +str(date[1])
    wdate_list.append(date_str)

# %%
len(wdate_list)
# Out:
# 104

# %%
ddate_list=[]
for date in dailysales.index.to_list():
    date_str = str(date[0])+" " +str(date[1])
    ddate_list.append(date_str)

# %%
plt.bar(date_list,monthlysales)
# Out:
# <BarContainer object of 25 artists>

# %%
plt.bar(wdate_list,weeklysales)
# Out:
# <BarContainer object of 104 artists>

# %%
X = dailysales
split = int(len(X) / 2)
X1, X2 = X[0:split], X[split:]
mean1, mean2 = X1.mean(), X2.mean()
var1, var2 = X1.var(), X2.var()
print('mean1=%f, mean2=%f' % (mean1, mean2))
print('variance1=%f, variance2=%f' % (var1, var2))
# Out:
# mean1=31999.050940, mean2=34110.554679
# variance1=253661374.872571, variance2=435260271.536530

# %%
plt.bar(ddate_list,dailysales)
# Out:
# <BarContainer object of 604 artists>

# %%
plt.boxplot(monthlysales)
# Out:
# {'whiskers': [<matplotlib.lines.Line2D at 0x247d383a9b0>,
# ...
#  'caps': [<matplotlib.lines.Line2D at 0x247d3839ae0>,
# ...
#  'boxes': [<matplotlib.lines.Line2D at 0x247c69633d0>],
#  'medians': [<matplotlib.lines.Line2D at 0x247d3825840>],
#  'fliers': [<matplotlib.lines.Line2D at 0x247d38276a0>],
#  'means': []}

# %%
plt.boxplot(weeklysales)
# Out:
# {'whiskers': [<matplotlib.lines.Line2D at 0x247d25f96c0>,
# ...
#  'caps': [<matplotlib.lines.Line2D at 0x247d25f9120>,
# ...
#  'boxes': [<matplotlib.lines.Line2D at 0x247d25fb880>],
#  'medians': [<matplotlib.lines.Line2D at 0x247d25e0e80>],
#  'fliers': [<matplotlib.lines.Line2D at 0x247d25e2aa0>],
#  'means': []}

# %%
plt.boxplot(dailysales)
# Out:
# {'whiskers': [<matplotlib.lines.Line2D at 0x247b24ad6c0>,
# ...
#  'caps': [<matplotlib.lines.Line2D at 0x247b24ac460>,
# ...
#  'boxes': [<matplotlib.lines.Line2D at 0x247b24ad780>],
#  'medians': [<matplotlib.lines.Line2D at 0x247b24acee0>],
#  'fliers': [<matplotlib.lines.Line2D at 0x247b246b5b0>],
#  'means': []}

# %%
X = weeklysales
split = int(len(X) / 2)
X1, X2 = X[0:split], X[split:]
mean1, mean2 = X1.mean(), X2.mean()
var1, var2 = X1.var(), X2.var()
print('mean1=%f, mean2=%f' % (mean1, mean2))
print('variance1=%f, variance2=%f' % (var1, var2))
# Out:
# mean1=186435.039500, mean2=197509.208519
# variance1=4599938511.899564, variance2=6977808330.386294

# %%
X = monthlysales
split = int(len(X) / 2)
X1, X2 = X[0:split], X[split:]
mean1, mean2 = X1.mean(), X2.mean()
var1, var2 = X1.var(), X2.var()
print('mean1=%f, mean2=%f' % (mean1, mean2))
print('variance1=%f, variance2=%f' % (var1, var2))
# Out:
# mean1=792578.916167, mean2=804165.684846
# variance1=63721138227.633347, variance2=71875083318.664978

# %%
from statsmodels.tsa.stattools import adfuller

# %%
X = dailysales
result = adfuller(X)
print('ADF Statistic: %f' % result[0])
print('p-value: %f' % result[1])
print('Critical Values:')
for key, value in result[4].items():
	print('\t%s: %.3f' % (key, value))
# Out:
# ADF Statistic: -0.381579
# p-value: 0.913129
# Critical Values:
# 	1%: -3.442
# 	5%: -2.866
# 	10%: -2.569

# %%
X = weeklysales
result = adfuller(X)
print('ADF Statistic: %f' % result[0])
print('p-value: %f' % result[1])
print('Critical Values:')
for key, value in result[4].items():
	print('\t%s: %.3f' % (key, value))
# Out:
# ADF Statistic: -0.323284
# p-value: 0.922141
# Critical Values:
# 	1%: -3.498
# 	5%: -2.891
# 	10%: -2.582

# %%
X = monthlysales
result = adfuller(X)
print('ADF Statistic: %f' % result[0])
print('p-value: %f' % result[1])
print('Critical Values:')
for key, value in result[4].items():
	print('\t%s: %.3f' % (key, value))
# Out:
# ADF Statistic: -3.057274
# p-value: 0.029881
# Critical Values:
# 	1%: -3.964
# 	5%: -3.085
# 	10%: -2.682

# %%
datasales.groupby(['Year', 'Month'])['Sales'].count()
# Out:
# Year  Month
# 2009  12       43376
# 2010  1        30263
#       2        27868
#       3        39684
#       4        32734
#       5        33295
#       6        38284
#       7        32011
#       8        32019
#       9        40478
#       10       56766
#       11       74833
#       12       40882
# 2011  1        33966
#       2        26803
#       3        35368
#       4        28794
#       5        35802
#       6        35601
#       7        38275
#       8        34148
#       9        48744
#       10       58350
#       11       81774
#       12       24770
# Name: Sales, dtype: int64

# %%
datasales.groupby(['Year', 'Week'])['Sales'].count()
# Out:
# Year  Week
# 2009  49      13942
#       50      12873
#       51      13606
#       52       2955
# 2010  1        4156
#               ...
# 2011  45      18662
#       46      20352
#       47      19220
#       48      18311
#       49      17239
# Name: Sales, Length: 104, dtype: int64

# %%
from prophet import Prophet

# %%
m = Prophet()

# %%
prophetdf = pd.DataFrame()

# %%
prophetdf['ds'] = datasales['InvoiceDate'].dt.date
prophetdf['y'] = datasales['Sales']

# %%
prophetdf
# Out:
#                  ds       y
# 0        2009-12-01   83.40
# 1        2009-12-01   81.00
# 2        2009-12-01   81.00
# 3        2009-12-01  100.80
# 4        2009-12-01   30.00
# ...             ...     ...
# 1004883  2011-12-09   10.20
# 1004884  2011-12-09   12.60
# 1004885  2011-12-09   16.60
# 1004886  2011-12-09   16.60
# 1004887  2011-12-09   14.85
#
# [1004888 rows x 2 columns]

# %%
prophetdfd = prophetdf.groupby(prophetdf['ds']).sum()

# %%
prophetdfc = prophetdf.groupby(prophetdf['ds']).count()

# %%
prophetdfc
# Out:
#                y
# ds
# 2009-12-01  3062
# 2009-12-02  3207
# 2009-12-03  2930
# 2009-12-04  2473
# 2009-12-05   400
# ...          ...
# 2011-12-05  5247
# 2011-12-06  3199
# 2011-12-07  2350
# 2011-12-08  4830
# 2011-12-09  1613
#
# [604 rows x 1 columns]

# %%
prophetdfd.to_csv('sales_prophet.csv')

# %%
prophetdfd.tail(5)
# Out:
#                     y
# ds
# 2011-12-05   87938.49
# 2011-12-06   55993.69
# 2011-12-07   74660.55
# 2011-12-08   82066.29
# 2011-12-09  200741.98

# %%
prophetdfd.sort_values(by = 'y',ascending=True).tail(20)
# Out:
#                      y
# ds
# 2009-12-03   73922.450
# 2011-12-07   74660.550
# 2011-10-05   74881.770
# 2011-09-15   75745.870
# 2010-11-29   78812.160
# 2011-11-23   79530.050
# 2010-11-10   79740.460
# 2011-12-08   82066.290
# 2010-11-08   83809.791
# 2010-12-07   84871.930
# 2011-11-07   85276.300
# 2010-10-14   87008.940
# 2011-12-05   87938.490
# 2010-11-04   89514.680
# 2011-01-18   95454.330
# 2010-09-27  102709.770
# 2010-11-15  104568.960
# 2011-09-20  109456.550
# 2011-11-14  113367.950
# 2011-12-09  200741.980

# %%
m.fit(prophetdf)
# Out:
# ---------------------------------------------------------------------------
# Exception                                 Traceback (most recent call last)
# Input In [112], in <cell line: 1>()
# ----> 1 m.fit(prophetdf)
#
# File ~\anaconda3\envs\datasci\lib\site-packages\prophet\forecaster.py:1104, in Prophet.fit(self, df, **kwargs)
#    1079 """Fit the Prophet model.
#    1080
#    1081 This sets self.params to contain the fitted model parameters. It is a
#    (...)
#    1101 The fitted Prophet object.
#    1102 """
#    1103 if self.history is not None:
# -> 1104     raise Exception('Prophet object can only be fit once. '
#    1105                     'Instantiate a new object.')
#    1106 if ('ds' not in df) or ('y' not in df):
#    1107     raise ValueError(
#    1108         'Dataframe must have columns "ds" and "y" with the dates and '
#    1109         'values respectively.'
#    1110     )
#
# Exception: Prophet object can only be fit once. Instantiate a new object.

# %%
m.add_country_holidays(country_name='UK')

# %%
future = m.make_future_dataframe(periods=180)

# %%
forecast = m.predict(future)

# %%
fig1 = m.plot(forecast)
